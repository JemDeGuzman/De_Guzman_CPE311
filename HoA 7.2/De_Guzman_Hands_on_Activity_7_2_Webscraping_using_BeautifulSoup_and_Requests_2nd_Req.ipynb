# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Requesting OutsideHTML of the website
url = 'https://sulit.ph/list-of-hospitals-in-metro-manila-with-contact-details-website-and-social-media-accounts/'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
# Finding the table from the HTML
table = soup.find('table')

# %%
# Finding the table headers
labels = table.find_all('th')

# %%
# Storing just the header values in a list
table_categories = [title.text for title in labels]
table_categories
# Out:
# ['CITY',
#  'NAME OF HOSPITAL',
#  'CONTACT NUMBER',
#  'WEBSITE / EMAIL',
#  'FACEBOOK LINK']

# %%
# Creating a DataFrame using the columns list
hospitals = pd.DataFrame(columns = table_categories)
hospitals
# Out:
# Empty DataFrame
# Columns: [CITY, NAME OF HOSPITAL, CONTACT NUMBER, WEBSITE / EMAIL, FACEBOOK LINK]
# Index: []

# %%
# Finding all the row data from the table
column_data = table.find_all('tr')

# %%
# Adding each row value into the DataFrame
for row in column_data[3:]:
  row_data = row.find_all('td')
  indiv_row_data = [data.text for data in row_data]

  length = len(hospitals)
  hospitals.loc[length] = indiv_row_data

hospitals
# Out:
#           CITY                                   NAME OF HOSPITAL  \
# 0     Caloocan                       Caloocan City Medical Center
# 1     Caloocan  Dr. Jose N. Rodriguez Memorial Hospital and Sa...
# 2     Caloocan             MCU – FDT Medical Foundations Hospital
# 3     Caloocan                       Metro Balayan Medical Center
# 4    Las Pinas                             Alabang Medical Center
# ..         ...                                                ...
# 91      Taguig                           Medical Center of Taguig
# 92  Valenzuela           Allied Care Experts (ACE) Medical Center
# 93  Valenzuela                   Fatima University Medical Center
# 94  Valenzuela                 Valenzuela Citicare Medical Center
# 95  Valenzuela                          Valenzuela Medical Center
#
#                                        CONTACT NUMBER  \
# 0     South 5310 7925, North 8282 3397, 0943 216 6963
# 1                      0966 549 2697, 8294 2571 to 73
# 2                                           8367 2031
# 3                                      (043) 740 1350
# 4                                8807 8189, 8850 8719
# ..                                                ...
# 91                                          8888 6284
# 92  direct line to Admission 0917 844 3654, 8332 0...
# 93                                          8291 6538
# 94                               8860 9300, 8860 9300
# 95                                          8294 6711
#
#                       WEBSITE / EMAIL  \
# 0
# 1           http://djnrmh.doh.gov.ph/
# 2        https://www.mcuhospital.org/
# 3   http://www.metrobalayanmc.com.ph/
# 4
# ..                                ...
# 91
# 92
# 93
# 94        http://www.citicare.com.ph/
# 95             http://vmc.doh.gov.ph/
#
#                                         FACEBOOK LINK
# 0   https://www.facebook.com/Caloocan-City-Medical...
# 1            https://www.facebook.com/officialDJNRMHS
# 2
# 3              https://www.facebook.com/metrobalayan/
# 4       https://www.facebook.com/alabangmedicalcenter
# ..                                                ...
# 91         https://www.facebook.com/mctadminofficial/
# 92  https://www.facebook.com/ACEMC-Valenzuela-Offi...
# 93
# 94                https://www.facebook.com/vcmcthpgi/
# 95              https://www.facebook.com/vmc.doh.gov/
#
# [96 rows x 5 columns]

# %%
# Saving the DataFrame as a CSV file
hospitals.to_csv('/content/hospitals.csv', index=False)

# %%
# Reading the hospitals.csv file
hospitals = pd.read_csv('/content/hospitals.csv')
hospitals.head()
# Out:
#         CITY                                   NAME OF HOSPITAL  \
# 0   Caloocan                       Caloocan City Medical Center
# 1   Caloocan  Dr. Jose N. Rodriguez Memorial Hospital and Sa...
# 2   Caloocan             MCU – FDT Medical Foundations Hospital
# 3   Caloocan                       Metro Balayan Medical Center
# 4  Las Pinas                             Alabang Medical Center
#
#                                     CONTACT NUMBER  \
# 0  South 5310 7925, North 8282 3397, 0943 216 6963
# 1                   0966 549 2697, 8294 2571 to 73
# 2                                        8367 2031
# 3                                   (043) 740 1350
# 4                             8807 8189, 8850 8719
#
#                      WEBSITE / EMAIL  \
# 0                                NaN
# 1          http://djnrmh.doh.gov.ph/
# 2       https://www.mcuhospital.org/
# 3  http://www.metrobalayanmc.com.ph/
# 4                                NaN
#
#                                        FACEBOOK LINK
# 0  https://www.facebook.com/Caloocan-City-Medical...
# 1           https://www.facebook.com/officialDJNRMHS
# 2                                                NaN
# 3             https://www.facebook.com/metrobalayan/
# 4      https://www.facebook.com/alabangmedicalcenter

# %%
# Checking the column datatypes
hospitals.dtypes
# Out:
# CITY                object
# NAME OF HOSPITAL    object
# CONTACT NUMBER      object
# WEBSITE / EMAIL     object
# FACEBOOK LINK       object
# dtype: object

# %%
# Dropping the Website/Email and Facebook Link columns
hospitals = hospitals.drop(['WEBSITE / EMAIL','FACEBOOK LINK'], axis=1)
hospitals
# Out:
#           CITY                                   NAME OF HOSPITAL  \
# 0     Caloocan                       Caloocan City Medical Center
# 1     Caloocan  Dr. Jose N. Rodriguez Memorial Hospital and Sa...
# 2     Caloocan             MCU – FDT Medical Foundations Hospital
# 3     Caloocan                       Metro Balayan Medical Center
# 4    Las Pinas                             Alabang Medical Center
# ..         ...                                                ...
# 91      Taguig                           Medical Center of Taguig
# 92  Valenzuela           Allied Care Experts (ACE) Medical Center
# 93  Valenzuela                   Fatima University Medical Center
# 94  Valenzuela                 Valenzuela Citicare Medical Center
# 95  Valenzuela                          Valenzuela Medical Center
#
#                                        CONTACT NUMBER
# 0     South 5310 7925, North 8282 3397, 0943 216 6963
# 1                      0966 549 2697, 8294 2571 to 73
# 2                                           8367 2031
# 3                                      (043) 740 1350
# 4                                8807 8189, 8850 8719
# ..                                                ...
# 91                                          8888 6284
# 92  direct line to Admission 0917 844 3654, 8332 0...
# 93                                          8291 6538
# 94                               8860 9300, 8860 9300
# 95                                          8294 6711
#
# [96 rows x 3 columns]

# %%
# Rearranging columns
hospitals = hospitals[['NAME OF HOSPITAL','CITY','CONTACT NUMBER']]
hospitals
# Out:
#                                      NAME OF HOSPITAL        CITY  \
# 0                        Caloocan City Medical Center    Caloocan
# 1   Dr. Jose N. Rodriguez Memorial Hospital and Sa...    Caloocan
# 2              MCU – FDT Medical Foundations Hospital    Caloocan
# 3                        Metro Balayan Medical Center    Caloocan
# 4                              Alabang Medical Center   Las Pinas
# ..                                                ...         ...
# 91                           Medical Center of Taguig      Taguig
# 92           Allied Care Experts (ACE) Medical Center  Valenzuela
# 93                   Fatima University Medical Center  Valenzuela
# 94                 Valenzuela Citicare Medical Center  Valenzuela
# 95                          Valenzuela Medical Center  Valenzuela
#
#                                        CONTACT NUMBER
# 0     South 5310 7925, North 8282 3397, 0943 216 6963
# 1                      0966 549 2697, 8294 2571 to 73
# 2                                           8367 2031
# 3                                      (043) 740 1350
# 4                                8807 8189, 8850 8719
# ..                                                ...
# 91                                          8888 6284
# 92  direct line to Admission 0917 844 3654, 8332 0...
# 93                                          8291 6538
# 94                               8860 9300, 8860 9300
# 95                                          8294 6711
#
# [96 rows x 3 columns]

# %%
# Checking for NaN values in the DataFrame
hospitals.isnull().sum().sum()
# Out:
# 0
